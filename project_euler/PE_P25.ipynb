# %%
fn_1 = 1
fn_2 = 1
curr_idx = 2
while True:
    curr_fn = fn_1 + fn_2
    curr_idx += 1
    if len(str(curr_fn)) == 1000:
        break
    fn_1 = fn_2
    fn_2 = curr_fn

print(curr_idx, curr_fn)
# Out:
# 4782 ...
